# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get("https://www.megabox.co.kr/movie-detail/comment?rpstMovieNo=21033000")

# %%
import time
time.sleep(2)

temp_list = [['score', 'genre', 'review']]
time.sleep(3)
for i in range(3):
    for j in range(1, 11):
        score = driver.find_elements_by_css_selector("#contentData > div > div.movie-idv-story > ul > li > div.story-area > div.story-box > div > div.story-cont > div.story-point > span")
        genre = driver.find_elements_by_css_selector("#contentData > div > div.movie-idv-story > ul > li > div.story-area > div.story-box > div > div.story-cont > div.story-recommend > em")
        review = driver.find_elements_by_css_selector("#contentData > div > div.movie-idv-story > ul > li > div.story-area > div.story-box > div > div.story-cont > div.story-txt")
        for s, g, r in zip(score, genre, review):
            temp_list.append([s.text, g.text, r.text])
        if j != 10:
            driver.find_element_by_css_selector("#contentData > div > div.movie-idv-story > nav > a:nth-child(" + str(j + 1) + ")")
        else:
            next_b = driver.find_element_by_css_selector("#contentData > div > div.movie-idv-story > nav > a.control.next")

with open('../output/movie.csv', "wt", encoding="utf-8") as f:
    for item in temp_list:
        f.write(str(item) + '\n')

#driver.quit()
# Out:
# ['score', 'genre', 'review']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
# ['10', '배우', '재밌게봤어요 감동ㅎ']
# ['10', '연출', '가족 모두 만족하며 봤어요!']
# ['10', '배우', '나름 감동도 있고 재미잏었어요...']
# ['10', '영상미', '재밌게 잘보았습니다!^-^']
# ['10', '배우', '눈물이 나네요. 정부는 시골 정차역 없애는거 중단해라!']
# ['6', '배우', '괜찮았어요 괜찮았어요']
# ['10', '스토리', '따뜻한 감성이 묻어나는 영화']
# ['10', '배우', '재밌었어요 감동감동']
# ['10', '영상미', '배우 연기도 스토리도 연출도 다 좋았습니다 오랜만에 본 저자극 영화']
# ['10', '배우', '박정민의연기는훌륭하나 너무나이들어보여서질감이나지않았다']
